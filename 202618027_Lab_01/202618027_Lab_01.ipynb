# %% [markdown]
# # **Task - 1**

# %% [markdown]
# **Step - 1: We need to create a scrapy project**
#
# Use - scrapy startproject tutorial
#
# Why this is needed?
# when the above command is ran in terminal a scrapy folder is created and it helps Scrapy to know that where the spider is, what setting are used, etc. If this is not done then scarpy won't be able to find the spider and scarpping could not be done.
#
# What actually is a Spider?
# it is like a web crawler. in the spider folder we create a class Spider because it navigates the scarpy that which is the website, which webpage to start and the whole pipeline is written in it.

# %% [markdown]
# **Step 2: After Scrapy project is created we need to create a Spider**
#
# Use - scrapy genspider books books.toscrape.com
# the spider named 'books' is created and it is linked to the url provided
#
# Why this?
# as given above scrapy uses it as a pipeline like what to do and if spider is not present than scrapy will not know how to proceed.
#
# Why was it hard to do this code in ipynb format?
# Because scrapy is not just a library. it is a framework like flask or django which needs it structure to work properly.

# %% [markdown]
# **Step 3: After creating all that it is time to create Spider**
#
# Reference - spiders/books.py

# %% [markdown]
# **Step 4: Now we need to run the spider to scrape all the data into csv file named raw_books.csv**
#
# use - scrapy crawl books
#
# how this command actually works?
# it first goes to scrapy.cfg to look where is the setting of the project in which spider is created.
# then it goes to settings.py where all the meta data is there
# then it looks inside spiders folder to find the 'books' spider
# once it finds books.py it runs the code where first class object is created and then crawler is started

# %% [markdown]
# **Step 5: Once the spider completes its task raw_books.csv is created and data is stored in it**
#
# Now it can be used Report the total number of scraped records, missing values, and duplicate UPC values.
#
# Reference - report_task1.py

# %% [markdown]
# # **Task - 2**
#
# Data Preprocessing
# ● Clean up extra spaces and inconsistent text; remove duplicate books by UPC; handle missing
# descriptions.
# ● Convert price to a numeric value, map ratings One-Five to integers, and extract the available stock
# count.
# ● Create at least three useful features, such as description_word_count, price_band, affordability_score,
# value_score, or recommended.
#
# Reference - preprocessing.py
#
# Output - After cleaning a new csv is created called 'cleaned_books.csv'

# %% [markdown]
# # **Task - 3**
#
# Visualization and Analysis
# ● Generate at least four meaningful plots, including price distribution, rating distribution, average price
# by category, and one relationship plot such as price vs rating or category vs stock.
# ● Generate a word cloud from the combined book descriptions. The selected website does not provide
# written customer-review text, so descriptions must be used as the textual source.
# ● Use summary statistics and plots to identify category patterns, highly rated books, stock patterns, and
# any unusual or missing values.
#
# Reference - analysis.py
#
# Output - images are created for all the categories provided above

# %% [markdown]
# # **Task - 4**
#
# **Write 5-7 clear observations supported by numerical results or plots.**
# - at first there were 2 missing values in product_description column which reduced to 0 after preprocessing the data
# - maximum books have price range between 20 to 25 euro
# - also maximum number of books have rating 1 and
# - average price of suspense genre is the highest
# - scatter plot of price vs rating is evenly distributed for all the rating
# - erotica, cultural, crime and politics genre have highest number of stock of books
# - the word cloud shows that maximum words in description are one, book, way, etc.
#
# **Explain whether price appears related to rating, which categories are most represented or expensive,**
# **and which books provide the best value.**
# - scatter plot is the best way to show relation between numerical variables but in the scatter there is no particular relation found between the 2 and overlapping is very much. Due to this we also try box plot because in box plot even minute highs and lows will be visible. Green line in box is median price. seeing the box plot now we can confirm that there is no relationship between price and rating as distribution is similar and there is very less difference in mean.
# - bar plot best shows the expensive category and it is suspence. other expensive categories are novels, politics, health and so on.
# - some of the best value books are An Abundance of Katherines, Greek Mythic History, The Power Greens Cookbook, Dear Mr. Knightley, etc. they have rating of 5 and values score is arounf 0.5 and 0.45. this is found using analysis.py code
#
#
# **Conclude with a brief discussion of the limitations of the scraped dataset and the analysis.**
# - the biggest limitation can be that if website is not scrappable then dataset cannot be formed and if the website is scrappable then the data present in it is questionable like is the data even true to do analysis
# - the data that we scrapped right now is for just the data available right now, if the data changes than we need to scrape it again like the stock of books can change.
# - this can also be one limitation that scarpped data is not very much clean and even to clean the dataset efforts need to be done
